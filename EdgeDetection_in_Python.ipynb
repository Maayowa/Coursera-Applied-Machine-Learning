# %% [markdown]
# <a href="https://colab.research.google.com/github/Maayowa/Coursera-Applied-Machine-Learning/blob/master/EdgeDetection_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np

# %%
from google.colab.patches import cv2_imshow
path = "/content/panda-black-white-study.jpg"

img = cv2.imread(path, 0)

# Using the Canny Edge detector
canny = cv2.Canny(img, 100, 200,)

# Checkout Laplacian Gradient
laplace = cv2.Laplacian(img, cv2.CV_64F, ksize = 3)
laplace = np.uint8(np.absolute(laplace))

# Sobel Gradient
sobelx = cv2.Sobel(img, cv2.CV_64F, 1,0, ksize = 5,)
sobely = cv2.Sobel(img, cv2.CV_64F, 0,1, ksize = 5)


#sobelxy = cv2.bitwise_or()


for title, img in zip(['img', 'cannydetect', 'laplacedetect', 'sobelx', 'sobely'], [img, canny, laplace, sobelx, sobely]):
  print('\n' + title + ':\n')
  cv2_imshow(img)
# Out:
# img:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDC78710>
# cannydetect:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDD1F650>
# laplacedetect:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDC78E10>
# sobelx:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDC78450>
# sobely:
# <PIL.Image.Image image mode=L size=1024x628 at 0x7F9EDDE16CD0>
